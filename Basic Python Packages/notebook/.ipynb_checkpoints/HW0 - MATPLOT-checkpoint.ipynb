# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# (a) Create two one dimensional arrays x and y and plot y vs x, add title, xlabel, ylabel, grid.
#
# ```python
# import numpy as np
# import matplotlib.pyplot as plt
#
#
# x = np.linspace(-5, 5, num=20)
# y = np.array([j ** 2 for j in x])
# ```
#
# copy the code above to the following cell and add code for plotting the parabola.

# %%
x = np.arange(6)
y = np.array([j ** 2 for j in x])
x
# Out:
# array([0, 1, 2, 3, 4, 5])

# %%
plt.plot(y, x, 'r')
plt.xlabel('Data of array Y')
plt.ylabel('Data of array X')
plt.title('Y vs X')
plt.grid(True)
plt.show()

# %% [markdown]
# What happens if the independent variable is not sorted before plotting? Try plotting directly using the following defined array.
#
# ```python
# import numpy as np
# import matplotlib.pyplot as plt
#
#
# x = np.linspace(-5, 5, num=20)
# np.random.shuffle(x)
# y = np.array([j ** 2 for j in x])
# ```

# %%
x = np.linspace(-5, 5, num=10)
shuffle = x.copy()
print(x)
print("Before shuffle ", shuffle)
np.random.shuffle(shuffle)
print("After shuffle ", shuffle)
y = np.array([j ** 2 for j in x])
# Out:
# [-5.         -3.88888889 -2.77777778 -1.66666667 -0.55555556  0.55555556
#   1.66666667  2.77777778  3.88888889  5.        ]
# Before shuffle  [-5.         -3.88888889 -2.77777778 -1.66666667 -0.55555556  0.55555556
#   1.66666667  2.77777778  3.88888889  5.        ]
# After shuffle  [ 5.          0.55555556 -3.88888889 -5.          1.66666667 -2.77777778
#   3.88888889 -1.66666667 -0.55555556  2.77777778]

# %%
plt.plot(shuffle, y)
plt.plot(x, y)
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('Shuffle vs No- Shuffle')
plt.grid(True)
plt.show()

# %% [markdown]
# (b) Create multiple arrays and plot them with different styles, add legends, add text/mathematical equations on the plot.
#
# ```python
# import numpy as np
# import matplotlib.pyplot as plt
#
#
# x = np.linspace(-5, 5, num=20)
# y1 = np.array([j for j in x])
# y2 = np.array([j ** 2 for j in x])
# y3 = np.array([j ** 3 for j in x])
# ```
#
# copy the code above to the following cell and add code for plotting curve $\left(x, y1\right)$, $\left(x, y2\right)$ and $\left(x, y3\right)$.

# %%
x = np.linspace(-5, 5, num=20)
y1 = np.array([j for j in x])
y2 = np.array([j ** 2 for j in x])
y3 = np.array([j ** 3 for j in x])

# %%
plt.scatter(x, y1, label="X vs Y1", color="g")
plt.scatter(x, y2, label="X vs Y2", color="r")
plt.scatter(x, y3, label="X vs Y3", color="b")
plt.legend()
plt.xlabel("X label")
plt.ylabel(" Y label")
plt.grid(True)
plt.show()

# %% [markdown]
# (c) Create multiple arrays and plot them into one figure **(No multiple figure and no subplot is allowed in this question)**.

# %%
plt.plot(x, y1,'r')
plt.plot(x, y3, 'g')
plt.plot(x, y2,'b')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('Multiple plots')
plt.grid(True)
plt.show()

# %% [markdown]
# (d) Create multiple subplots, play around with the figure size, figure title, and its font style and font size **(One curve is plotted in one subplot in this question)**.
#
# ```python
# import numpy as np
# import matplotlib.pyplot as plt
#
#
# x = np.linspace(-5, 5, num=20)
# y1 = np.array([j for j in x])
# y2 = np.array([j ** 2 for j in x])
# y3 = np.array([j ** 3 for j in x])
# ```
#
# copy the code above to the following cell and add code for plotting curve $\left(x, y1\right)$, $\left(x, y2\right)$ and $\left(x, y3\right)$.

# %%
plt.figure(figsize=(12, 5))
fig, ((ax1, ax2, ax3)) = plt.subplots(1, 3)
fig.suptitle('Multiple plots in different subplots', fontsize=14, fontweight='bold')
ax1.set_title('X vs Y1')
ax2.set_title('X vs Y2')
ax3.set_title('X vs Y3')

# ax.set_xlabel('xlabel')
# ax.set_ylabel('ylabel')
ax1.plot(x, y1, 'tab:red')
ax1.set(xlabel='x-label', ylabel='y1-label')
ax2.plot(x, y2, 'tab:orange')
ax2.set(xlabel='x-label')#, ylabel='y2-label')
ax3.plot(x, y3, 'tab:green')
ax3.set(xlabel='x-label')#, ylabel='y3-label')
# Out:
# [Text(0.5, 0, 'x-label')]

# %% [markdown]
# (e) Change the limits on x and y axes, **use logarithmic axes to plot**.
#
# ```python
# import numpy as np
# import matplotlib.pyplot as plt
#
#
# x = np.linspace(-5, 5, num=20)
# y = np.array([j ** 2 for j in x])
# ```
#
# copy the code above to the following cell and add code for plotting the parabola.

# %%
x = np.linspace(-5, 5, num=20)
#y = np.array([j ** 2 for j in x])
y = x**2 + 2*x + 2

# %%
plt.plot(x,y, 'r')
plt.yscale('log')

plt.grid(True,which="both", linestyle='--')
plt.xlabel('X axis')
plt.ylabel('Y axis (LOG)')
plt.title('PARABOLA on a log scale', fontsize=8)
plt.show()
